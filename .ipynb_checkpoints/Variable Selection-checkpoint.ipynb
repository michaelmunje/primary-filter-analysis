# %%
import pandas as pd
df = pd.read_csv('phase2-res.csv')

feats_df = df.drop(columns=['Filename', 'Output'])
Y = df['Output']
df.head()
# Out:
#      HistMean      HistVar      LaplVar     MaxLapl       MaxVar  MaxAvgLapl  \
# 0  172.465515   720.605256   613.496113  255.283676  3141.374252  297.757073
# 1  114.768188  9042.951879  1075.129234  299.942612  5497.009506  601.463473
# 2   85.229126  5737.952018   989.958606  465.874008  5698.864609  487.412923
# 3   79.706726  5033.211659  1190.971659  374.875717  8084.393661  545.449855
# 4   93.042786  6122.234436   932.756638  109.927353  7019.038086  553.311266
#
#      IQR    Deviation  C1AreaProp  C4AreaProp  ...  SurfNumKP  AkazeNumKP  \
# 0   29.0    22.579438    0.353271    0.356812  ...        103           4
# 1  200.0  2099.592821    0.219666    0.224182  ...         69           6
# 2  153.0   245.102714    0.204712    0.210571  ...         59           8
# 3  134.0   507.546173    0.217834    0.218750  ...         72           2
# 4  165.0  1823.800329    0.218262    0.220032  ...         65           5
#
#    KazeNumKP  ORBNumKP  RidgeAreaProp   AvgMaxX   MaxY      MinVar  \
# 0         27       127       0.422052   44643.0  32988  107.880293
# 1         65        27       0.238823  595215.0  55707   89.108415
# 2         61        94       0.282823  378452.0  36999  141.611445
# 3         60        50       0.271832  411315.0  42144  182.914684
# 4         44       101       0.287259  498016.0  89109   75.190465
#
#                                         Filename Output
# 0   ESP_011314_1585_RED.NOMAP.browse-Block-7.jpg      1
# 1  ESP_011325_1845_RED.NOMAP.browse-Block-10.jpg      1
# 2  ESP_011325_1845_RED.NOMAP.browse-Block-12.jpg      1
# 3  ESP_011325_1845_RED.NOMAP.browse-Block-14.jpg      1
# 4  ESP_011325_1845_RED.NOMAP.browse-Block-16.jpg      1
#
# [5 rows x 21 columns]

# %%
def get_filename(index):
    return df.iloc[index]['Filename']

def get_column(x_name):
    index = int(x_name.split('x')[1])
    return df.drop(columns=['Output', 'Filename']).columns[index-1]

# %%
import utilities as utils
utils.print_log_regression_metrics(feats_df.values, Y)
# Out:
# C:\Users\Michael\Anaconda3\envs\machine-learning\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\Michael\Anaconda3\envs\machine-learning\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Accuracy: 0.852
# [[904  35   7  10   8]
#  [107 298   3   0   1]
#  [ 14   1  30   9  47]
#  [ 19   0   2  55   1]
#  [  6   3  14   1 370]]
# C:\Users\Michael\Anaconda3\envs\machine-learning\lib\site-packages\sklearn\utils\optimize.py:203: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   "number of iterations.", ConvergenceWarning)

# %%
import statsmodels.api as sm
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod import families
import statsmodels.stats.tests.test_influence

X2 = sm.add_constant(feats_df.values)

#fit = sm.MNLogit(Y, X2)
#fit = model.fit(method='newton', maxiter=500)
#print(fit.summary())

# %%
import numpy as np

def forward_selection(df):
    all_features = df.columns
    current_features = []
    
    x2 = np.ones(len(df))
    model = sm.MNLogit(Y, x2)
    fit = model.fit(method='newton', maxiter=500)
    current_aic = fit.aic
    print(current_aic)
    
    for i in range(len(all_features)):
        print("Step " + str(i+1))
        aics = []
        for j in range(len(all_features)):
            # Attempt to add feat j
            if all_features[j] in current_features:
                aics.append(1000000000000000000)
                continue
            x = feats_df[current_features + [all_features[j]]].values
            x2 = sm.add_constant(x)
            model = sm.MNLogit(Y, x2)
            fit = model.fit(method='newton', maxiter=500)
            aics.append(fit.aic)
        if min(aics) >= current_aic:
            break
        else:
            current_features.append(all_features[np.argmin(aics)])
            current_aic = min(aics)
    return current_features

# %%
features = forward_selection(feats_df)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.280666
#          Iterations 6
# 4989.7892164980885
# Step 1
# Optimization terminated successfully.
#          Current function value: 1.252285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.242690
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.924917
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.790898
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.955071
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 1.058727
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 1.233792
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.265044
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.269236
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.235506
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 1.172875
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 1.252568
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.179702
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 1.229980
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 1.093873
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 1.165032
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 1.051094
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 1.194015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 1.228482
#          Iterations 6
# Step 2
# Optimization terminated successfully.
#          Current function value: 0.766280
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.784672
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.705924
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.710423
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.787008
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.787140
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.775270
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.772279
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.755684
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.773732
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.786456
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.775159
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.773369
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.755152
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.717696
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.622750
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.771653
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.767345
#          Iterations 11
# Step 3
# Optimization terminated successfully.
#          Current function value: 0.596275
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.615803
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.540108
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.530153
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.612878
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.615273
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.610269
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.615591
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.601563
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.607164
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.608111
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.610850
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.609001
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.590666
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.543776
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.572640
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.590662
#          Iterations 11
# Step 4
# Optimization terminated successfully.
#          Current function value: 0.517370
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.523301
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.482173
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.521956
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.524281
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.523325
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.525960
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.522450
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.518818
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.525962
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.519840
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.523797
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.511602
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.491581
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.499572
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.514842
#          Iterations 13
# Step 5
# Optimization terminated successfully.
#          Current function value: 0.468019
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.475045
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.464031
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.476585
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.479093
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.456665
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.479167
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.462975
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.440981
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.473922
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.466099
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.472310
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.469323
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.454585
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.468666
#          Iterations 13
# Step 6
# Optimization terminated successfully.
#          Current function value: 0.429877
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.435505
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.435379
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.436460
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.439279
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.436008
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.439308
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.433504
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.434081
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.437155
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.432495
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.431766
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.415777
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.429024
#          Iterations 13
# Step 7
# Optimization terminated successfully.
#          Current function value: 0.406502
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.411244
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.410998
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.412139
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.414365
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.407451
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.409726
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.407593
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.408583
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.411654
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.407277
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.402152
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.412415
#          Iterations 13
# Step 8
# Optimization terminated successfully.
#          Current function value: 0.395025
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.399982
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.397557
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.400422
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.400781
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.395817
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.399891
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.394695
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.396844
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.400146
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.393946
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.396671
#          Iterations 13
# Step 9
# Optimization terminated successfully.
#          Current function value: 0.386842
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.391398
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.389775
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.392019
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.392620
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.387452
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.391552
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.392407
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.389661
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.392636
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.387875
#          Iterations 13
# Step 10
# Optimization terminated successfully.
#          Current function value: 0.384715
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.383170
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.385249
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.385445
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.380885
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.384377
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.385448
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.382707
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.385542
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.380795
#          Iterations 13
# Step 11
# Optimization terminated successfully.
#          Current function value: 0.378317
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.377439
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.378816
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.379366
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.374916
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.378328
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.379288
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.376123
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.379754
#          Iterations 13
# Step 12
# Optimization terminated successfully.
#          Current function value: 0.372744
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.372878
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.373202
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.373922
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.372565
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.373195
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.371250
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.373676
#          Iterations 13
# Step 13
# Optimization terminated successfully.
#          Current function value: 0.369714
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.368614
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.370032
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.370254
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.368073
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.369398
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.367294
#          Iterations 13
# Step 14
# Optimization terminated successfully.
#          Current function value: 0.365458
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.364019
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.365893
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.366402
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.365843
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.365587
#          Iterations 13
# Step 15
# Optimization terminated successfully.
#          Current function value: 0.361768
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.362347
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.363148
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.362556
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.362578
#          Iterations 13
# Step 16
# Optimization terminated successfully.
#          Current function value: 0.361301
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.360871
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.360279
#          Iterations 14
# Optimization terminated successfully.
#          Current function value: 0.360493
#          Iterations 13

# %%
features
# Out:
# ['MaxLapl',
#  'AvgMaxX',
#  'MaxVar',
#  'LaplVar',
#  'SurfNumKP',
#  'MaxY',
#  'RidgeAreaProp',
#  'ORBNumKP',
#  'HistMean',
#  'MinVar',
#  'C1AreaProp',
#  'AkazeNumKP',
#  'KazeNumKP',
#  'MaxAvgLapl',
#  'HistVar']

# %%
out_df = feats_df[features].copy()
out_df['Output'] = df['Output']
out_df['Filename'] = df['Filename']
out_df.to_csv('phase3-var-sel.csv', index=False)
